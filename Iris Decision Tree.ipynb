# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
df = pd.read_csv('C:/Users/KEMI- ITB CONCRETE/Downloads/datasetsIris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Check data types
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.drop(columns=['Id'], inplace=True)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#Check if there are missing values
df.isnull().any()
# Out:
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
#Check data summary
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#Check relationship between columns
sns.pairplot(df,hue='Species')

# %%
#Split Dataset into train and test
df_inputs = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
df_inputs
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
df_classes = df['Species'].values
df_classes
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
#Train_Test_Split
(train_inputs,test_inputs,train_classes,test_classes) = train_test_split(df_inputs,df_classes,train_size=0.7,random_state=1)
(train_inputs,test_inputs,train_classes,test_classes)
# Out:
# (array([[7.7, 2.6, 6.9, 2.3],
#         [5.7, 3.8, 1.7, 0.3],
#         [5. , 3.6, 1.4, 0.2],
#         [4.8, 3. , 1.4, 0.3],
#         [5.2, 2.7, 3.9, 1.4],
#         [5.1, 3.4, 1.5, 0.2],
#         [5.5, 3.5, 1.3, 0.2],
#         [7.7, 3.8, 6.7, 2.2],
#         [6.9, 3.1, 5.4, 2.1],
#         [7.3, 2.9, 6.3, 1.8],
#         [6.4, 2.8, 5.6, 2.2],
#         [6.2, 2.8, 4.8, 1.8],
#         [6. , 3.4, 4.5, 1.6],
#         [7.7, 2.8, 6.7, 2. ],
#         [5.7, 3. , 4.2, 1.2],
#         [4.8, 3.4, 1.6, 0.2],
#         [5.7, 2.5, 5. , 2. ],
#         [6.3, 2.7, 4.9, 1.8],
#         [4.8, 3. , 1.4, 0.1],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.5, 3. , 5.8, 2.2],
#         [4.6, 3.4, 1.4, 0.3],
#         [6.1, 3. , 4.9, 1.8],
#         [6.5, 3.2, 5.1, 2. ],
#         [6.7, 3.1, 4.4, 1.4],
#         [5.7, 2.8, 4.5, 1.3],
#         [6.7, 3.3, 5.7, 2.5],
#         [6. , 3. , 4.8, 1.8],
#         [5.1, 3.8, 1.6, 0.2],
#         [6. , 2.2, 4. , 1. ],
#         [6.4, 2.9, 4.3, 1.3],
# ...

# %%
(train_inputs,test_inputs,train_classes,test_classes) = train_test_split(df_inputs,df_classes,test_size=0.3,random_state=1)
(train_inputs,test_inputs,train_classes,test_classes)
# Out:
# (array([[7.7, 2.6, 6.9, 2.3],
#         [5.7, 3.8, 1.7, 0.3],
#         [5. , 3.6, 1.4, 0.2],
#         [4.8, 3. , 1.4, 0.3],
#         [5.2, 2.7, 3.9, 1.4],
#         [5.1, 3.4, 1.5, 0.2],
#         [5.5, 3.5, 1.3, 0.2],
#         [7.7, 3.8, 6.7, 2.2],
#         [6.9, 3.1, 5.4, 2.1],
#         [7.3, 2.9, 6.3, 1.8],
#         [6.4, 2.8, 5.6, 2.2],
#         [6.2, 2.8, 4.8, 1.8],
#         [6. , 3.4, 4.5, 1.6],
#         [7.7, 2.8, 6.7, 2. ],
#         [5.7, 3. , 4.2, 1.2],
#         [4.8, 3.4, 1.6, 0.2],
#         [5.7, 2.5, 5. , 2. ],
#         [6.3, 2.7, 4.9, 1.8],
#         [4.8, 3. , 1.4, 0.1],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.5, 3. , 5.8, 2.2],
#         [4.6, 3.4, 1.4, 0.3],
#         [6.1, 3. , 4.9, 1.8],
#         [6.5, 3.2, 5.1, 2. ],
#         [6.7, 3.1, 4.4, 1.4],
#         [5.7, 2.8, 4.5, 1.3],
#         [6.7, 3.3, 5.7, 2.5],
#         [6. , 3. , 4.8, 1.8],
#         [5.1, 3.8, 1.6, 0.2],
#         [6. , 2.2, 4. , 1. ],
#         [6.4, 2.9, 4.3, 1.3],
# ...

# %%
#Decision Tress
dtc = DecisionTreeClassifier()
dtc.fit(train_inputs,train_classes)
dtc.score(test_inputs,test_classes)
# Out:
# 0.9555555555555556

# %%
from sklearn import tree
text_representation = tree.export_text(dtc)
print(text_representation)
# Out:
# |--- feature_2 <= 2.60
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.60
# |   |--- feature_3 <= 1.65
# |   |   |--- feature_2 <= 5.00
# |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  5.00
# |   |   |   |--- feature_0 <= 6.05
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_0 >  6.05
# |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.65
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(text_representation)

# %%
fig = plt.figure(figsize=(25,20))

# %%
#Visualizing into Decision Tree
tree.plot_tree(dtc)
# Out:
# [Text(133.92000000000002, 195.696, 'X[2] <= 2.6\ngini = 0.665\nsamples = 105\nvalue = [36, 32, 37]'),
#  Text(100.44000000000001, 152.208, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
#  Text(167.40000000000003, 152.208, 'X[3] <= 1.65\ngini = 0.497\nsamples = 69\nvalue = [0, 32, 37]'),
#  Text(66.96000000000001, 108.72, 'X[2] <= 5.0\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(33.480000000000004, 65.232, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(100.44000000000001, 65.232, 'X[0] <= 6.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(66.96000000000001, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(133.92000000000002, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(267.84000000000003, 108.72, 'X[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]'),
#  Text(234.36, 65.232, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
# ...

# %%
[Text(133.92000000000002, 195.696, 'X[2] <= 2.6\ngini = 0.665\nsamples = 105\nvalue = [36, 32, 37]'),
 Text(100.44000000000001, 152.208, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]'),
 Text(167.40000000000003, 152.208, 'X[3] <= 1.65\ngini = 0.497\nsamples = 69\nvalue = [0, 32, 37]'),
 Text(66.96000000000001, 108.72, 'X[2] <= 5.0\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
 Text(33.480000000000004, 65.232, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
 Text(100.44000000000001, 65.232, 'X[0] <= 6.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
 Text(66.96000000000001, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
 Text(133.92000000000002, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
 Text(267.84000000000003, 108.72, 'X[2] <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]'),
 Text(234.36, 65.232, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
 Text(200.88000000000002, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
 Text(267.84000000000003, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
 Text(301.32000000000005, 65.232, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]

1st row and column, adding colour and saving the image
#Using the 1st row and column, adding colour and saving the image
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(dtc, feature_names = fn, class_names=cn, filled = True)
fig.savefig('IrisDCT.png')
